# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 46     |  |
# | :-------------|:-------------|
# | Cedric Peignier | 6577458 |
# | Lukas Calixtro| 6528619 |
# | Oscar Pouw| 6409806 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 46     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 11:15 klaar | Oscar |
# | ontwerp-eis berekenen| 12u klaar | Cedric & Lukas |
# | schetsen (2 pp) | tot 14u | hele groep |
# | bouwen | vanaf 14u | hele groep |
# | schetsen (2 pp) | 14u af | hele groep |
# | 1e ontwerp & bouwsel af | 15:30 | hele groep |
# | Pauze 1| 12:30-13:30 | hele groep |
# | Pauze 2| 16:00-16:20 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 7 |
# | hoe lang voor één meting |  5 mins|
# | verwacht nauwkeurigheid meting | 1 hz, 10mm |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %% [markdown]
# $$ f_n = \frac{1}{2 \pi} \sqrt{\frac{C}{m}} $$
# $$ \omega _0 = \sqrt{\frac{C}{m}} $$
# $$ f_n = \frac{\omega _0}{2 \pi} $$
# Dempingsfactor = 3, frequentie = 5Hz $ \rightarrow $
# $$ \frac{A_m}{A_v} = \frac{1}{3} $$
# $$ \omega = 2 \pi f = 10 \pi $$
# $$ -\frac{A_m}{A_v} = \frac{1}{1-\frac{(\omega)^2}{(\omega _0)^2}} $$
# $$ -\frac{1}{3} = \frac{1}{1-\frac{(10 \pi)^2}{\omega _0^2}} $$
# $$ -\frac{1}{3} = \frac{1}{1-\frac{100 \pi^2}{\omega _0^2}} $$
# $$ 1/a = 1/b \rightarrow a = b $$
# $$ -3 = 1-\frac{100 \pi^2}{\omega _0^2} $$
# $$ 4 = \frac{100 \pi^2}{\omega _0^2} $$
# $$ 4 \omega _0^2 = 100 \pi^2 $$
# $$ \omega _0^2 = 25 \pi^2 $$
# $$ \omega _0 = \sqrt{25 \pi^2} $$
# $$ \omega _0 = 5 \pi $$
# $$ f_n = \frac{\omega _0}{2 \pi} $$
# $$ f_n = \frac{5 \pi}{2 \pi} $$
# $$ f_n = \frac{5}{2} $$

# %%
f_0 = 5/2 #Hz
omega_0 = 5 * np.pi
omega_vast = 10 * np.pi
f = 5 #Hz
print(omega_0)
# Out:
# 15.707963267948966

# %%
omega_array = np.linspace(0,100,1000)
A_mA_v = np.abs(1/(1-(((omega_array)**2)/(omega_0)**2)))

plt.figure(figsize=(12,8))
plt.loglog(omega_array,A_mA_v,'o-')
plt.xlabel('log(ω) (rad)')
plt.ylabel('log(Am/Av) (Hz)')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# $$ \omega _0 = 5 \pi $$
# $$ \delta x = \frac{g}{\omega _0^2} $$
# $$ \delta x = \frac{g}{(5 \pi)^2} $$
# $$ \delta x = \frac{g}{(25 \pi^2)} $$
# $$ \delta x \approx \frac{10}{25 \pi^2} $$
# $$ \delta x \approx 0.04 m $$

# %%
delta_x_min = 9.81/(25 * np.pi**2)
g = 9.81
print(delta_x_min)
# Out:
# 0.039758432461253344

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

m_array = np.linspace(0,5,100)
C_array = m_array * (g/delta_x_min)
C_array2 = m_array * (g/(2 *delta_x_min))
C_array5 = m_array * (g/(5 * delta_x_min))


plt.figure(figsize=(12,8))
plt.plot(m_array,C_array,'o-', label='delta_x_min')
plt.plot(m_array,C_array2,'r-', label='delta_x_min * 2')
plt.plot(m_array,C_array5,'g-', label='delta_x_min * 5')
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.legend()
plt.show()
plt.savefig('dx plot')

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - Lengte omhoog
# - Massa omhoog
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van:  0.08 m

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# <img src="Schets_1.png" width="400">
# <img src="Schets_2.png" width="400">
# <img src="Schets_3.png" width="400">
# <img src="Schets_4.png" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# 0.08m
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# Ja.
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **Voeg hier je antwoord in**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Ja.
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# Ja.
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
omega_opstelling0 = np.sqrt((0.75 * (g/(2 *delta_x_min)))/0.75)

A_mA_v_opstelling = np.abs(1/(1-(((omega_array)**2)/(omega_opstelling0)**2)))
A_mA_v = np.abs(1/(1-(((omega_array)**2)/(omega_0)**2)))


plt.figure(figsize=(12,8))
plt.loglog(omega_array,A_mA_v_opstelling,'--ob',label = "Opstelling")
plt.loglog(omega_array,A_mA_v,'--or',label = "Originele")
plt.xlabel('log(ω) (rad)')
plt.ylabel('log(Am/Av) (Hz)')
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
omega_gemeten = np.array([1.4,2.0,3.6,3.8,4.5,5.75,6.5,7,7.8,15.6])*(2 * np.pi)
A1 = np.array([1.2,1.4,2.0,0.34,3.92,5.86,6.3,2.8,6.5,6.16])
A_unc = np.array([1,1.1,1,0.2,1.6,1.2,2.1,2.2,2.5,2.3])
A2 = np.array([1.01,1.2,1.7,0.39,2.43,2.31,1.85,1.5,1.9,5.49])
A_ver = A2/(A1)


omega_opstelling0 = np.sqrt((2.5 * (g/(2 *delta_x_min)))/2.5)

A_mA_v_opstelling = np.abs(1/(1-(((omega_array)**2)/(np.pi)**2)))
A_mA_v = np.abs(1/(1-(((omega_array)**2)/(omega_0)**2)))


plt.figure(figsize=(12,8))
plt.plot(omega_array,A_mA_v_opstelling,'--ob')
plt.plot(omega_array,A_mA_v,'--or')
plt.errorbar(omega_gemeten,A_ver, 1, A_unc,'o')
plt.xlabel('log(ω) (rad)')
plt.ylabel('log(Am/Av) (Hz)')
plt.xscale('log')
plt.yscale('log')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# *Uitleg voor dit;
# Zijwaardse trillingen werden niet gecompenseerd en zouden kunnen hebben gezorgd voor inconsistentie bij de arduino
# Trillingen werden mogelijkerwijze inconsistent uitgevoerd

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %% [markdown]
# Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen:

# %% [markdown]
# $$ f_n = \frac{1}{2 \pi} \sqrt{\frac{C}{m}} $$
# $$ \omega _0 = \sqrt{\frac{C}{m}} $$
# $$ f_n = \frac{\omega _0}{2 \pi} $$
# Dempingsfactor = 3, frequentie = 5Hz $ \rightarrow $
# $$ \frac{A_m}{A_v} = \frac{1}{3} $$
# $$ \omega = 2 \pi f = 10 \pi $$
# $$ -\frac{A_m}{A_v} = \frac{1}{1-\frac{(\omega)^2}{(\omega _0)^2}} $$
# $$ -\frac{1}{3} = \frac{1}{1-\frac{(10 \pi)^2}{\omega _0^2}} $$
# $$ -\frac{1}{3} = \frac{1}{1-\frac{100 \pi^2}{\omega _0^2}} $$
# $$ 1/a = 1/b \rightarrow a = b $$
# $$ -3 = 1-\frac{100 \pi^2}{\omega _0^2} $$
# $$ 4 = \frac{100 \pi^2}{\omega _0^2} $$
# $$ 4 \omega _0^2 = 100 \pi^2 $$
# $$ \omega _0^2 = 25 \pi^2 $$
# $$ \omega _0 = \sqrt{25 \pi^2} $$
# $$ \omega _0 = 5 \pi $$
# $$ f_n = \frac{\omega _0}{2 \pi} $$
# $$ f_n = \frac{5 \pi}{2 \pi} $$
# $$ f_n = \frac{5}{2} $$
# $$ \omega _0 = 5 \pi $$
# $$ \delta x = \frac{g}{\omega _0^2} $$
# $$ \delta x = \frac{g}{(5 \pi)^2} $$
# $$ \delta x = \frac{g}{(25 \pi^2)} $$
# $$ \delta x \approx \frac{10}{25 \pi^2} $$
# $$ \delta x \approx 0.04 m $$

# %%
f_0 = 5/2 #Hz
omega_0 = 5 * np.pi
omega_vast = 10 * np.pi
f = 5 #Hz
delta_x_min = 9.81/(25 * np.pi**2)
g = 9.81

# %% [markdown]
# Op basis van een differentiaalvergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp:

# %%
omega_gemeten = np.array([1.4,2.0,3.6,3.8,4.5,5.75,6.5,7,7.8,15.6])*(2 * np.pi)
A1 = np.array([1.2,1.4,2.0,0.34,3.92,5.86,6.3,2.8,6.5,6.16])
A_unc = np.array([1,1.1,1,0.2,1.6,1.2,2.1,2.2,2.5,2.3])
A2 = np.array([1.01,1.2,1.7,0.39,2.43,2.31,1.85,1.5,1.9,5.49])
A_ver = A2/(A1)


omega_opstelling0 = np.sqrt((2.5 * (g/(2 *delta_x_min)))/2.5)

A_mA_v_opstelling = np.abs(1/(1-(((omega_array)**2)/(np.pi)**2)))
A_mA_v = np.abs(1/(1-(((omega_array)**2)/(omega_0)**2)))


plt.figure(figsize=(12,8))
plt.plot(omega_array,A_mA_v_opstelling,'--ob')
plt.plot(omega_array,A_mA_v,'--or')
plt.errorbar(omega_gemeten,A_ver, 1, A_unc,'o')
plt.xlabel('log(ω) (rad)')
plt.ylabel('log(Am/Av) (Hz)')
plt.xscale('log')
plt.yscale('log')
plt.show


#*Uitleg voor dit; 
#Zijwaardse trillingen werden niet gecompenseerd en zouden kunnen hebben gezorgd voor inconsistentie bij de arduino 
#Trillingen werden mogelijkerwijze inconsistent uitgevoerd
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# <img src="Opstelling_1.jpeg" width="400">
# <img src="Opstelling_2.jpeg" width="400">
# <img src="Opstelling_schets.jpeg" width="400">

# %% [markdown]
# *De video die op brightspace staat moet hier nog bij
